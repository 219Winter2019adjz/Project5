# %%
import pandas as pd

# %% [markdown]
# #### Question 8

# %%
results = pd.read_csv('gs_q8.csv')
results
# Out:
#       Unnamed: 0  mean_fit_time  mean_score_time  mean_test_score  \
# 0              0       0.289471         0.011395    -2.478961e+08
# 1              1       0.504117         0.023402    -2.461217e+08
# 2              2       0.698558         0.038809    -2.472197e+08
# 3              3       0.956014         0.057013    -2.456824e+08
# 4              4       1.164661         0.073417    -2.433705e+08
# 5              5       1.417920         0.078615    -2.466288e+08
# 6              6       1.655171         0.101023    -2.462106e+08
# 7              7       1.869019         0.114426    -2.447256e+08
# 8              8       2.141080         0.126828    -2.464216e+08
# 9              9       2.388336         0.146033    -2.467273e+08
# 10            10       0.298866         0.012603    -2.488577e+08
# 11            11       0.512117         0.026004    -2.462959e+08
# 12            12       0.711159         0.043810    -2.484109e+08
# ...

# %%
results.sort_values('mean_train_score', ascending=False).iloc[0:10, 3:15]
# Out:
#       mean_test_score  mean_train_score  \
# 1914    -2.968355e+08     -9.751669e-08
# 2278    -2.876557e+08     -9.774702e-08
# 2816    -2.927531e+08     -9.824336e-08
# 2817    -2.903553e+08     -9.825939e-08
# 2095    -2.975746e+08     -9.827454e-08
# 1726    -2.696460e+08     -9.828218e-08
# 1916    -2.935841e+08     -9.828905e-08
# 2272    -3.001059e+08     -9.834345e-08
# 1825    -2.775348e+08     -9.840784e-08
# 1826    -2.789479e+08     -9.840784e-08
#
#                                         param_estimator  \
# 1914  GradientBoostingRegressor(alpha=0.9, criterion...
# 2278  GradientBoostingRegressor(alpha=0.9, criterion...
# 2816  GradientBoostingRegressor(alpha=0.9, criterion...
# 2817  GradientBoostingRegressor(alpha=0.9, criterion...
# 2095  GradientBoostingRegressor(alpha=0.9, criterion...
# 1726  GradientBoostingRegressor(alpha=0.9, criterion...
# 1916  GradientBoostingRegressor(alpha=0.9, criterion...
# 2272  GradientBoostingRegressor(alpha=0.9, criterion...
# ...

# %%
print(results.sort_values('mean_test_score', ascending=False).iloc[0:10, :].to_latex(columns=('mean_test_score', 'mean_train_score', 'param_estimator', 'param_estimator__max_depth', 'param_estimator__max_features', 'param_estimator__min_samples_leaf', 'param_estimator__min_samples_split', 'param_estimator__n_estimators')))
# Out:
# \begin{tabular}{lrrlrlrrr}
# \toprule
# {} &  mean\_test\_score &  mean\_train\_score &                                    param\_estimator &  param\_estimator\_\_max\_depth & param\_estimator\_\_max\_features &  param\_estimator\_\_min\_samples\_leaf &  param\_estimator\_\_min\_samples\_split &  param\_estimator\_\_n\_estimators \\
# \midrule
# 2143 &    -2.061977e+08 &     -56849.752986 &  GradientBoostingRegressor(alpha=0.9, criterion... &                        60.0 &                          sqrt &                                  4 &                                   5 &                            800 \\
# 2866 &    -2.065202e+08 &      -2931.518875 &  GradientBoostingRegressor(alpha=0.9, criterion... &                         NaN &                          sqrt &                                  4 &                                   5 &                           1400 \\
# ...

# %% [markdown]
# #### Question 10, before

# %%
results = pd.read_csv('gs_q10_1.csv')
results
# Out:
#       Unnamed: 0  mean_fit_time  mean_score_time  mean_test_score  \
# 0              0       0.139824         0.001600    -6.533136e+06
# 1              1       0.224450         0.002400    -6.930674e+06
# 2              2       0.253659         0.002404    -7.272303e+06
# 3              3       0.278471         0.003001    -7.076980e+06
# 4              4       0.302870         0.002602    -6.704201e+06
# 5              5       0.327484         0.002601    -7.762119e+06
# 6              6       0.356689         0.003001    -6.310875e+06
# 7              7       0.382091         0.002801    -6.941948e+06
# 8              8       0.407891         0.003001    -6.699429e+06
# 9              9       0.432501         0.003000    -6.798399e+06
# 10            10       0.111230         0.001200    -7.513772e+06
# 11            11       0.219657         0.002199    -8.937862e+06
# 12            12       0.279468         0.002601    -8.221152e+06
# ...

# %%
results.sort_values('mean_train_score', ascending=False).iloc[0:10, 3:15]
# Out:
#       mean_test_score  mean_train_score  \
# 1177    -7.450655e+06     -9.791104e-08
# 273     -5.884768e+06     -9.816307e-08
# 281     -7.014432e+06     -9.816854e-08
# 814     -6.209493e+06     -9.826176e-08
# 284     -6.665789e+06     -9.828792e-08
# 1352    -5.987079e+06     -9.830238e-08
# 999     -6.913749e+06     -9.832070e-08
# 283     -6.500693e+06     -9.834646e-08
# 665     -6.449417e+06     -9.837683e-08
# 1205    -6.189892e+06     -9.839739e-08
#
#                                         param_estimator  \
# 1177  GradientBoostingRegressor(alpha=0.9, criterion...
# 273   GradientBoostingRegressor(alpha=0.9, criterion...
# 281   GradientBoostingRegressor(alpha=0.9, criterion...
# 814   GradientBoostingRegressor(alpha=0.9, criterion...
# 284   GradientBoostingRegressor(alpha=0.9, criterion...
# 1352  GradientBoostingRegressor(alpha=0.9, criterion...
# 999   GradientBoostingRegressor(alpha=0.9, criterion...
# 283   GradientBoostingRegressor(alpha=0.9, criterion...
# ...

# %%
print(results.sort_values('mean_test_score', ascending=False).iloc[0:10, :].to_latex(columns=('mean_test_score', 'mean_train_score', 'param_estimator', 'param_estimator__max_depth', 'param_estimator__max_features', 'param_estimator__min_samples_leaf', 'param_estimator__min_samples_split', 'param_estimator__n_estimators')))
# Out:
# \begin{tabular}{lrrlrlrrr}
# \toprule
# {} &  mean\_test\_score &  mean\_train\_score &                                    param\_estimator &  param\_estimator\_\_max\_depth & param\_estimator\_\_max\_features &  param\_estimator\_\_min\_samples\_leaf &  param\_estimator\_\_min\_samples\_split &  param\_estimator\_\_n\_estimators \\
# \midrule
# 141  &    -5.689844e+06 &     -5.711139e-01 &  GradientBoostingRegressor(alpha=0.9, criterion... &                        10.0 &                          sqrt &                                  2 &                                  10 &                            400 \\
# 321  &    -5.695530e+06 &     -7.716574e-02 &  GradientBoostingRegressor(alpha=0.9, criterion... &                        20.0 &                          sqrt &                                  2 &                                  10 &                            400 \\
# ...

# %% [markdown]
# #### Question 10, during

# %%
results = pd.read_csv('gs_q10_2.csv')
results
# Out:
#       Unnamed: 0  mean_fit_time  mean_score_time  mean_test_score  \
# 0              0       0.056608         0.000400    -4.698649e+07
# 1              1       0.081820         0.000800    -4.710560e+07
# 2              2       0.106826         0.001000    -4.613566e+07
# 3              3       0.135434         0.001000    -4.644390e+07
# 4              4       0.159238         0.001202    -4.678428e+07
# 5              5       0.185041         0.001200    -4.668263e+07
# 6              6       0.206846         0.001201    -4.726119e+07
# 7              7       0.231056         0.001199    -4.692395e+07
# 8              8       0.257464         0.001400    -4.584426e+07
# 9              9       0.280665         0.001600    -4.697058e+07
# 10            10       0.053616         0.000400    -4.323893e+07
# 11            11       0.093620         0.001000    -4.306151e+07
# 12            12       0.120430         0.001000    -4.350874e+07
# ...

# %%
results.sort_values('mean_train_score', ascending=False).iloc[0:10, 3:15]
# Out:
#       mean_test_score  mean_train_score  \
# 293     -3.496834e+07     -9.597059e-08
# 653     -3.213143e+07     -9.636772e-08
# 297     -3.309969e+07     -9.672596e-08
# 1008    -3.407271e+07     -9.722795e-08
# 1378    -3.310036e+07     -9.744858e-08
# 639     -3.139440e+07     -9.748776e-08
# 1170    -3.322767e+07     -9.765706e-08
# 292     -3.448633e+07     -9.767559e-08
# 828     -3.518477e+07     -9.777873e-08
# 1372    -3.512983e+07     -9.781509e-08
#
#                                         param_estimator  \
# 293   GradientBoostingRegressor(alpha=0.9, criterion...
# 653   GradientBoostingRegressor(alpha=0.9, criterion...
# 297   GradientBoostingRegressor(alpha=0.9, criterion...
# 1008  GradientBoostingRegressor(alpha=0.9, criterion...
# 1378  GradientBoostingRegressor(alpha=0.9, criterion...
# 639   GradientBoostingRegressor(alpha=0.9, criterion...
# 1170  GradientBoostingRegressor(alpha=0.9, criterion...
# 292   GradientBoostingRegressor(alpha=0.9, criterion...
# ...

# %%
print(results.sort_values('mean_test_score', ascending=False).iloc[0:10, :].to_latex(columns=('mean_test_score', 'mean_train_score', 'param_estimator', 'param_estimator__max_depth', 'param_estimator__max_features', 'param_estimator__min_samples_leaf', 'param_estimator__min_samples_split', 'param_estimator__n_estimators')))
# Out:
# \begin{tabular}{lrrlrlrrr}
# \toprule
# {} &  mean\_test\_score &  mean\_train\_score &                                    param\_estimator &  param\_estimator\_\_max\_depth & param\_estimator\_\_max\_features &  param\_estimator\_\_min\_samples\_leaf &  param\_estimator\_\_min\_samples\_split &  param\_estimator\_\_n\_estimators \\
# \midrule
# 270  &    -2.848297e+07 &     -9.900099e-08 &  GradientBoostingRegressor(alpha=0.9, criterion... &                        20.0 &                          sqrt &                                  1 &                                   2 &                            200 \\
# 92   &    -2.908657e+07 &     -9.872871e-08 &  GradientBoostingRegressor(alpha=0.9, criterion... &                        10.0 &                          sqrt &                                  1 &                                   2 &                            600 \\
# ...

# %% [markdown]
# #### Question 10, after

# %%
results = pd.read_csv('gs_q10_3.csv')
results
# Out:
#       Unnamed: 0  mean_fit_time  mean_score_time  mean_test_score  \
# 0              0       0.051406         0.000800   -667306.326422
# 1              1       0.075618         0.001001   -628348.848675
# 2              2       0.101423         0.001000   -649599.857867
# 3              3       0.126229         0.001000   -625115.826057
# 4              4       0.151634         0.001001   -660704.794146
# 5              5       0.175839         0.001000   -654878.195693
# 6              6       0.200445         0.001601   -695910.290987
# 7              7       0.227451         0.001401   -659789.595556
# 8              8       0.249856         0.001000   -665062.486150
# 9              9       0.276262         0.001200   -648748.069325
# 10            10       0.052412         0.000800   -496232.663450
# 11            11       0.079618         0.000800   -543162.766029
# 12            12       0.103823         0.001000   -481708.634766
# ...

# %%
results.sort_values('mean_train_score', ascending=False).iloc[0:10, 3:15]
# Out:
#       mean_test_score  mean_train_score  \
# 810    -495312.357315     -9.739027e-08
# 1175   -439868.487165     -9.745021e-08
# 47     -501048.627436     -9.746200e-08
# 49     -496140.379457     -9.746200e-08
# 46     -498973.241089     -9.746200e-08
# 48     -500437.225424     -9.746200e-08
# 45     -497420.973080     -9.746200e-08
# 43     -498808.918568     -9.746200e-08
# 44     -496809.323813     -9.746200e-08
# 462    -444819.554781     -9.752901e-08
#
#                                         param_estimator  \
# 810   GradientBoostingRegressor(alpha=0.9, criterion...
# 1175  GradientBoostingRegressor(alpha=0.9, criterion...
# 47    GradientBoostingRegressor(alpha=0.9, criterion...
# 49    GradientBoostingRegressor(alpha=0.9, criterion...
# 46    GradientBoostingRegressor(alpha=0.9, criterion...
# 48    GradientBoostingRegressor(alpha=0.9, criterion...
# 45    GradientBoostingRegressor(alpha=0.9, criterion...
# 43    GradientBoostingRegressor(alpha=0.9, criterion...
# ...

# %%
print(results.sort_values('mean_test_score', ascending=False).iloc[0:10, :].to_latex(columns=('mean_test_score', 'mean_train_score', 'param_estimator', 'param_estimator__max_depth', 'param_estimator__max_features', 'param_estimator__min_samples_leaf', 'param_estimator__min_samples_split', 'param_estimator__n_estimators')))
# Out:
# \begin{tabular}{lrrlrlrrr}
# \toprule
# {} &  mean\_test\_score &  mean\_train\_score &                                    param\_estimator &  param\_estimator\_\_max\_depth & param\_estimator\_\_max\_features &  param\_estimator\_\_min\_samples\_leaf &  param\_estimator\_\_min\_samples\_split &  param\_estimator\_\_n\_estimators \\
# \midrule
# 169  &   -331572.339233 &     -1.110052e-07 &  GradientBoostingRegressor(alpha=0.9, criterion... &                        10.0 &                          sqrt &                                  4 &                                   5 &                           2000 \\
# 1236 &   -336085.514476 &     -8.297246e-07 &  GradientBoostingRegressor(alpha=0.9, criterion... &                       200.0 &                          sqrt &                                  4 &                                   2 &                           1400 \\
# ...
